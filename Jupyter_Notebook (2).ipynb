# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Title : Final Assessment

# %% [markdown]
# # Introduction
#
# This is the final assessment for the tools in data sceince course

# %% [markdown]
# # Data Science Languages:-
#
# - Python
# - R
# - SQL

# %% [markdown]
# # Popular Data Science Libraries
#
# Here are some widely used Python libraries for data science:
#
# - **NumPy** – For numerical computations and array operations
# - **Pandas** – For data manipulation and analysis
# - **Matplotlib** – For data visualization
# - **Seaborn** – For statistical data visualization
# - **Scikit-learn** – For machine learning algorithms
# - **TensorFlow** – For deep learning and neural networks
# - **Keras** – High-level neural networks API
# - **PyTorch** – For deep learning and AI research

# %% [markdown]
# | **Data Science Tools** |
# |------------------------|
# | Jupyter Notebook       |
# | RStudio                |
# | Apache Zeppelin        |

# %% [markdown]
# In Python, arithmetic expressions are used to perform basic mathematical operations.
# Here are some common examples:
#
# - **Addition (`+`)**: `3 + 2` → 5
# - **Subtraction (`-`)**: `7 - 4` → 3
# - **Multiplication (`*`)**: `6 * 3` → 18
# - **Division (`/`)**: `8 / 2` → 4.0
# - **Exponentiation (`**`)**: `2 ** 3` → 8
# - **Modulus (`%`)**: `10 % 3` → 1

# %%
a=10
b=20
multiply=a*b
add=a+b
print(multiply)
print(add)
# Out:
# 200
# 30

# %%
hours=int(input("hours: "))
mins=hours*60
print(mins)
# Out:
# hours:  3
# 180

# %% [markdown]
# ## Objectives
# - Understand the basics of Jupyter Notebook
# - Use github
# - Update Repo

# %% [markdown]
# # Author : Chinmay Dinesh Kulkarni
